# %% [markdown]
# # Importing the Libraries

# %%
# lets import the basic Libraries
import numpy as np
import pandas as pd
import pandas_profiling as profile

# %%
# for data visualizations
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly

# %%
# for interactivity in the notebook
import ipywidgets as widgets
from ipywidgets import interact
from ipywidgets import interact_manual

# %% [markdown]
# # Reading the Dataset

# %%
# lets import the data
df = pd.read_csv('tarifftruck.csv')

# %% [markdown]
# ### Inspecting the Data

# %%
# Checking: Shape of data
df.shape
# Out:
# (289, 11)

# %%
# columns of the data
df.columns
# Out:
# Index(['year', 'road', 'seasonalimpact', 'demand', 'wttons', 'labour', 'toll',
#        'distance', 'fuelcost', 'miscellaneous', 'tariff'],
#       dtype='object')

# %%
# information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            289 non-null    int64
#  1   road            234 non-null    object
#  2   seasonalimpact  243 non-null    object
#  3   demand          258 non-null    object
#  4   wttons          288 non-null    float64
#  5   labour          289 non-null    int64
#  6   toll            289 non-null    int64
#  7   distance        285 non-null    float64
#  8   fuelcost        289 non-null    int64
#  9   miscellaneous   287 non-null    float64
#  10  tariff          289 non-null    int64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 25.0+ KB

# %%
# data types of the data
df.dtypes
# Out:
# year                int64
# road               object
# seasonalimpact     object
# demand             object
# wttons            float64
# labour              int64
# toll                int64
# distance          float64
# fuelcost            int64
# miscellaneous     float64
# tariff              int64
# dtype: object

# %%
data = df

# %% [markdown]
# # Dynamic of the Dataset

# %%
# lets check the head of the data
data.head()
# Out:
#    year road seasonalimpact demand  ...  distance  fuelcost  miscellaneous  tariff
# 0  2013   nh            yes   high  ...    1460.0     23534         9000.0   17950
# 1  2013   nh            yes   high  ...    1360.0     22184        10000.0   19710
# 2  2013   nh            yes   high  ...    1310.0     21476         9400.0   18600
# 3  2013   nh            yes   high  ...     650.0     10473         6000.0    9150
# 4  2013   nh            yes   high  ...     560.0      9417         5600.0    9700
#
# [5 rows x 11 columns]

# %%
# lets check the tail of the data
data.tail()
# Out:
#      year road seasonalimpact  ... fuelcost  miscellaneous  tariff
# 284  2015   sh            yes  ...     1592         6600.0    7040
# 285  2015  NaN            yes  ...     6002         7500.0    9760
# 286  2015  NaN            yes  ...     7541         7800.0   10703
# 287  2015   nh            yes  ...    14492         9500.0   14215
# 288  2015   nh            yes  ...    14778         8400.0   12744
#
# [5 rows x 11 columns]

# %%
# lets check the sample of the data
data.sample(3)
# Out:
#      year road seasonalimpact  ... fuelcost  miscellaneous  tariff
# 129  2014   nh            yes  ...    26953        11690.0   21386
# 258  2015   sh            yes  ...     1546         7450.0    8332
# 275  2015   nh             no  ...    15676         6200.0   12523
#
# [3 rows x 11 columns]

# %% [markdown]
# # Inferential Statistics

# %%
x = data.describe()
x.style.bar(color = ['silver', 'gold'], align = 'mid')
# Out:
# <style  type="text/css" >
# #T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 14.3%, transparent 14.3%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 43.6%, transparent 43.6%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 9.6%, transparent 9.6%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row0_col3,#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 1.5%, transparent 1.5%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 1.9%, transparent 1.9%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row0_col5,#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.6%, transparent 0.6%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row0_col6,#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row1_col1,#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row3_col5,#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 2.1%, transparent 2.1%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.9%, transparent 0.9%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row1_col0,#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row3_col0,#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 99.9%, transparent 99.9%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 30.3%, transparent 30.3%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 13.8%, transparent 13.8%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 4.1%, transparent 4.1%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 22.2%, transparent 22.2%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 51.3%, transparent 51.3%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 32.8%, transparent 32.8%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 5.8%, transparent 5.8%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 12.1%, transparent 12.1%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 14.4%, transparent 14.4%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 6.4%, transparent 6.4%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 16.3%, transparent 16.3%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 13.7%, transparent 13.7%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 14.0%, transparent 14.0%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row3_col2,#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row3_col3{
#             width:  10em;
#              height:  80%;
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.3%, transparent 0.3%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 29.9%, transparent 29.9%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.2%, transparent 0.2%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 1.3%, transparent 1.3%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 21.0%, transparent 21.0%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 2.8%, transparent 2.8%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row4_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 8.8%, transparent 8.8%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row4_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 40.9%, transparent 40.9%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row4_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 23.0%, transparent 23.0%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row5_col0,#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row6_col0,#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row7_col0,#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row7_col1,#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row7_col2,#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row7_col3,#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row7_col4,#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row7_col5,#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row7_col6,#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row7_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 100.0%, transparent 100.0%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 1.7%, transparent 1.7%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 29.3%, transparent 29.3%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row5_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 8.5%, transparent 8.5%);
#         }#T_5de261f0_9a8b_11eb_ac78_0242ac1c0002row5_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 3.1%, transparent 3.1%);

# %%
x = data.cov()
x.style.bar(color = ['silver', 'gold'], align = 'mid')
# Out:
# <style  type="text/css" >
# #T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 37.2%, gold 37.2%, gold 37.3%, transparent 37.3%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 54.0%, gold 54.0%, gold 54.0%, transparent 54.0%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.1%, gold 0.1%, gold 0.1%, transparent 0.1%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row0_col3,#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row0_col4,#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row0_col5,#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 0.0%, transparent 0.0%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.0%, transparent 0.0%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row0_col7,#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 0.0%, transparent 0.0%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 37.2%, gold 37.2%, gold 37.6%, transparent 37.6%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 54.0%, gold 54.0%, gold 60.9%, transparent 60.9%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 0.1%, transparent 0.1%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, silver 0.0%, silver 0.0%, transparent 0.0%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 0.1%, transparent 0.1%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 0.1%, transparent 0.1%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 37.2%, gold 37.2%, gold 45.4%, transparent 45.4%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.9%, silver 49.9%, silver 54.0%, transparent 54.0%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.1%, gold 0.1%, gold 9.9%, transparent 9.9%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row2_col3,#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 2.5%, transparent 2.5%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 6.3%, transparent 6.3%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 5.2%, transparent 5.2%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 3.7%, transparent 3.7%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 37.2%, transparent 37.2%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 53.6%, silver 53.6%, silver 54.0%, transparent 54.0%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.1%, gold 0.1%, gold 33.2%, transparent 33.2%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 42.6%, transparent 42.6%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 33.1%, transparent 33.1%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 33.5%, transparent 33.5%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 33.1%, transparent 33.1%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 39.1%, transparent 39.1%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 33.9%, silver 33.9%, silver 37.2%, transparent 37.2%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 54.0%, gold 54.0%, gold 68.1%, transparent 68.1%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.1%, gold 0.1%, gold 13.0%, transparent 13.0%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 5.1%, transparent 5.1%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 31.5%, transparent 31.5%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row4_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 5.2%, transparent 5.2%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row4_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 5.4%, transparent 5.4%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row4_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.0%, gold 0.0%, gold 4.3%, transparent 4.3%);
#         }#T_5de9e81c_9a8b_11eb_ac78_0242ac1c0002row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 15.9%, silver 15.9%, silver 37.2%, transparent 37.2%);
#         }#

# %%
x = data.corr()
x.style.bar(color = ['silver', 'gold'], align = 'mid')
# Out:
# <style  type="text/css" >
# #T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row0_col0,#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 10.3%, gold 10.3%, gold 100.0%, transparent 100.0%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 6.3%, gold 6.3%, gold 14.4%, transparent 14.4%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 5.9%, gold 5.9%, gold 23.8%, transparent 23.8%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row0_col3,#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 10.3%, transparent 10.3%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 2.9%, transparent 2.9%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 2.4%, transparent 2.4%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 28.1%, transparent 28.1%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 6.3%, gold 6.3%, gold 11.1%, transparent 11.1%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 10.3%, gold 10.3%, gold 18.0%, transparent 18.0%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row1_col1,#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row7_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 6.3%, gold 6.3%, gold 100.0%, transparent 100.0%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 5.9%, transparent 5.9%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 10.2%, silver 10.2%, silver 10.3%, transparent 10.3%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 2.9%, gold 2.9%, gold 11.1%, transparent 11.1%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 2.4%, gold 2.4%, gold 5.9%, transparent 5.9%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 70.5%, transparent 70.5%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row1_col7,#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,silver 6.3%, transparent 6.3%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 10.3%, gold 10.3%, gold 27.3%, transparent 27.3%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.4%, silver 0.4%, silver 6.3%, transparent 6.3%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 5.9%, gold 5.9%, gold 100.0%, transparent 100.0%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 10.3%, gold 10.3%, gold 50.3%, transparent 50.3%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 2.9%, gold 2.9%, gold 52.9%, transparent 52.9%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 2.4%, gold 2.4%, gold 52.0%, transparent 52.0%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 81.9%, transparent 81.9%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 6.3%, gold 6.3%, gold 67.5%, transparent 67.5%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 6.2%, silver 6.2%, silver 6.3%, transparent 6.3%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 5.9%, gold 5.9%, gold 47.9%, transparent 47.9%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 2.9%, gold 2.9%, gold 37.2%, transparent 37.2%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 2.4%, gold 2.4%, gold 88.9%, transparent 88.9%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 63.9%, transparent 63.9%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 6.3%, gold 6.3%, gold 92.7%, transparent 92.7%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 7.6%, silver 7.6%, silver 10.3%, transparent 10.3%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 6.3%, gold 6.3%, gold 14.2%, transparent 14.2%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 5.9%, gold 5.9%, gold 54.3%, transparent 54.3%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 10.3%, gold 10.3%, gold 42.0%, transparent 42.0%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 2.9%, gold 2.9%, gold 100.0%, transparent 100.0%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row4_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 2.4%, gold 2.4%, gold 41.9%, transparent 41.9%);
#         }#T_5defe9ba_9a8b_11eb_ac78_0242ac1c0002row4_col6{

# %%
# lets check the missing values present in the data
x = data.isnull().sum()
x = pd.DataFrame(x)
x.style.bar(color = ['lightgreen'], align = 'mid')
# Out:
# <style  type="text/css" >
# #T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002row0_col0,#T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002row5_col0,#T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002row6_col0,#T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002row8_col0,#T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002row10_col0{
#             width:  10em;
#              height:  80%;
#         }#T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
#         }#T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 83.6%, transparent 83.6%);
#         }#T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 56.4%, transparent 56.4%);
#         }#T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 1.8%, transparent 1.8%);
#         }#T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 7.3%, transparent 7.3%);
#         }#T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 3.6%, transparent 3.6%);
#         }</style><table id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002level0_row0" class="row_heading level0 row0" >year</th>
#                         <td id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002row0_col0" class="data row0 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002level0_row1" class="row_heading level0 row1" >road</th>
#                         <td id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002row1_col0" class="data row1 col0" >55</td>
#             </tr>
#             <tr>
#                         <th id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002level0_row2" class="row_heading level0 row2" >seasonalimpact</th>
#                         <td id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002row2_col0" class="data row2 col0" >46</td>
#             </tr>
#             <tr>
#                         <th id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002level0_row3" class="row_heading level0 row3" >demand</th>
#                         <td id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002row3_col0" class="data row3 col0" >31</td>
#             </tr>
#             <tr>
#                         <th id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002level0_row4" class="row_heading level0 row4" >wttons</th>
#                         <td id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002row4_col0" class="data row4 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002level0_row5" class="row_heading level0 row5" >labour</th>
#                         <td id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002row5_col0" class="data row5 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002level0_row6" class="row_heading level0 row6" >toll</th>
#                         <td id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002row6_col0" class="data row6 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002level0_row7" class="row_heading level0 row7" >distance</th>
#                         <td id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002row7_col0" class="data row7 col0" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002level0_row8" class="row_heading level0 row8" >fuelcost</th>
#                         <td id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002row8_col0" class="data row8 col0" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002level0_row9" class="row_heading level0 row9" >miscellaneous</th>
#                         <td id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002row9_col0" class="data row9 col0" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002level0_row10" class="row_heading level0 row10" >tariff</th>
#                         <td id="T_5df40fcc_9a8b_11eb_ac78_0242ac1c0002row10_col0" class="data row10 col0" >0</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Data Visualization

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
# lets check the columns again
data.columns
# Out:
# Index(['year', 'road', 'seasonalimpact', 'demand', 'wttons', 'labour', 'toll',
#        'distance', 'fuelcost', 'miscellaneous', 'tariff'],
#       dtype='object')

# %%
plt.rcParams['figure.figsize'] = (11, 6)
plt.style.use('seaborn-dark')

sns.scatterplot(data['miscellaneous'],data['tariff'],  color = 'red')
plt.title('Distance vs Fuel Cost', fontsize = 20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
# lets compare the toll and tariff rate

plt.rcParams['figure.figsize'] = (11, 6)
plt.style.use('dark_background')

sns.lineplot(data['distance'],data['fuelcost'],  color = 'red')
plt.title('Distance vs Fuel Cost', fontsize = 20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
# lets compare the toll and tariff rate

plt.rcParams['figure.figsize'] = (11, 6)
plt.style.use('ggplot')

sns.lineplot(data['year'],data['tariff'],  color = 'red')
plt.title('Tariff Rate Year wise Growth Trend', fontsize = 20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
# lets compare the toll and tariff rate

plt.rcParams['figure.figsize'] = (11, 6)
plt.style.use('seaborn-dark')

sns.scatterplot(data['tariff'], data['toll'], color = 'red')
plt.title('Tariff Rate Year wise Growth Trend', fontsize = 20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
# lets check the yearly growth in wttons

plt.rcParams['figure.figsize'] = (11, 6)
plt.style.use('seaborn-dark')

sns.boxenplot(data['year'], data['wttons'], color = 'purple')
plt.title('Tariff Rate Year wise Growth Trend', fontsize = 20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
# lets check the tariff rate year wise

plt.rcParams['figure.figsize'] = (11, 6)
plt.style.use('seaborn-dark')

sns.lineplot(data['year'], data['tariff'], color = 'purple')
plt.title('Tariff Rate Year wise Growth Trend', fontsize = 20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (11, 7)

sns.countplot(data['demand'], palette = 'copper')
plt.title('Pie Chart Representing Different Seasonal Impacts on Tariff Rate', fontsize = 20)
plt.xlabel('Demand')
plt.ylabel(' ')

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
plt.style.use('seaborn-darkgrid')
plt.rcParams['figure.figsize'] = (7, 7)

data['seasonalimpact'].value_counts().plot(kind = 'pie',
                                          colors = ['lightgreen','gold','silver'])
plt.title('Pie Chart Representing Different Seasonal Impacts on Tariff Rate', fontsize = 20)
plt.axis('off')
plt.show()

# %% [markdown]
# # Interactive Analysis

# %%
# lets check correlations

@interact
def check_correlation(column1 = list(data.select_dtypes('number').columns),
                      column2 = list(data.select_dtypes('number').columns[1:])):
    print(f"The Correlation is :", {data[column1].corr(data[column2])})
# Out:
# interactive(children=(Dropdown(description='column1', options=('year', 'wttons', 'labour', 'toll', 'distance',…

# %%
# lets check the covariances

@interact
def check_covariance(column1 = list(data.select_dtypes('number').columns),
                      column2 = list(data.select_dtypes('number').columns[1:])):
    print(f"The Covariance is :", {data[column1].cov(data[column2])})
# Out:
# interactive(children=(Dropdown(description='column1', options=('year', 'wttons', 'labour', 'toll', 'distance',…

# %%
# lets check the Maximum Values in each of the Columns

@interact
def check_maximum(column1 = list(data.select_dtypes('number').columns)):
    print(f"The Maximum Value is :", {data[column1].max()})
# Out:
# interactive(children=(Dropdown(description='column1', options=('year', 'wttons', 'labour', 'toll', 'distance',…

# %%
# lets check the Minimum Values in each of the Columns

@interact
def check_minimum(column1 = list(data.select_dtypes('number').columns)):
    print(f"The Minimum Value is :", {data[column1].min()})
# Out:
# interactive(children=(Dropdown(description='column1', options=('year', 'wttons', 'labour', 'toll', 'distance',…

# %%
# lets check the Standard Deviation in each of the Columns

@interact
def check_deviation(column1 = list(data.select_dtypes('number').columns)):
    print(f"The Standard Deviation is :", {data[column1].std()})
# Out:
# interactive(children=(Dropdown(description='column1', options=('year', 'wttons', 'labour', 'toll', 'distance',…

# %%
plt.rcParams['figure.figsize'] = (11, 7)

# %%
# lets check the scatter plots
plt.style.use('dark_background')

@interact_manual
def scatter_plot(column1 = list(data.select_dtypes('number').columns),
                column2 = list(data.select_dtypes('number').columns[1:])):
    data.plot(kind = 'scatter',
              color = 'white',
              x = column1,
              y = column2)
# Out:
# interactive(children=(Dropdown(description='column1', options=('year', 'wttons', 'labour', 'toll', 'distance',…

# %%
plt.style.use('ggplot')

@interact_manual
def scatter_plot(column1 = list(data.select_dtypes('number').columns),
                column2 = list(data.select_dtypes('number').columns[1:]),
                kind = ['scatter','line']):
    data.plot(kind = kind,
              color = 'black',
              x = column1,
              y = column2)
# Out:
# interactive(children=(Dropdown(description='column1', options=('year', 'wttons', 'labour', 'toll', 'distance',…

# %%
@interact_manual
def scatter_plot(column1 = list(data.select_dtypes('number').columns),
                column2 = list(data.select_dtypes('number').columns[1:]),
                kind = ['scatter','line'],
                color = ['black','red','green','yellow','pink']):
    data.plot(kind = kind,
              color = color,
              x = column1,
              y = column2)
# Out:
# interactive(children=(Dropdown(description='column1', options=('year', 'wttons', 'labour', 'toll', 'distance',…

# %%
@interact_manual
def scatter_plot(column1 = list(data.select_dtypes('object').columns),
                column2 = list(data.select_dtypes('number').columns[1:]),
                 palette = ['copper','spring','summer','Reds','Greens','Blues']):
    sns.boxenplot(
              data[column1],
              data[column2],
              palette = palette)
# Out:
# interactive(children=(Dropdown(description='column1', options=('road', 'seasonalimpact', 'demand'), value='roa…

# %% [markdown]
# # Variable Analysis

# %%
data.columns
# Out:
# Index(['year', 'road', 'seasonalimpact', 'demand', 'wttons', 'labour', 'toll',
#        'distance', 'fuelcost', 'miscellaneous', 'tariff'],
#       dtype='object')

# %%
sns.distplot(data['tariff'],
             color = 'black')
plt.title('Distribution of Tariff Rates', fontsize = 20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
sns.distplot(data['fuelcost'],
             color = 'red')
plt.title('Distribution of Fuel Cost', fontsize = 20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
sns.distplot(data['distance'],
             color = 'pink')
plt.title('Distribution of Distances Travelled', fontsize = 20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
sns.distplot(data['toll'],
             color = 'blue')
plt.title('Distribution of Toll Charges', fontsize = 20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
sns.distplot(data['labour'],
             color = 'yellow')
plt.title('Distribution of Labor Charges', fontsize = 20)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# lets do bi variate analysis

d1 = pd.crosstab(data['year'], data['seasonalimpact'],)
d1
# Out:
# seasonalimpact  high  no  yes
# year
# 2013               0  24   72
# 2014               0  42   55
# 2015               1  11   38

# %%
# lets plot the above data

d1.plot(kind = 'bar',
        stacked = False,
        color = ['silver', 'gold'])
plt.title('Seasonal Impact each Year', fontsize = 20)
plt.show()

# %%
# demand vs year

d2 = pd.crosstab(data['year'], data['demand'],)
d2
# Out:
# demand  6  high  less  low  normal
# year
# 2013    0    28    33    0      46
# 2014    0    45    23    0      37
# 2015    1    21     0    8      16

# %%
# lets plot the above data

d2.plot(kind = 'bar',
        color = ['pink', 'gold','crimson','lightgreen','silver'],)
plt.title('Demand each year', fontsize = 20)
plt.show()

# %%
# heatmap for correlation

plt.rcParams['figure.figsize'] = (12, 7)
sns.heatmap(data.corr(),
            cmap = 'Blues',
            annot = True)
plt.title('Heatmap for Correlation', fontsize = 20)
plt.show()

# %%
# heatmap for covariance

sns.heatmap(data.cov(),
            cmap = 'copper',
            annot = True)
plt.title('Covariance of the Data', fontsize = 20)
plt.show()

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Computing missing Values

# %%
# lets check the mean value of wttons as it of integer type
data['wttons'].mean()
# Out:
# 13.630694444444444

# %%
# lets impute that one missing value with the median value instead of mean value 
data['wttons'] = data['wttons'].fillna(data['wttons'].mean())
print("Median Value of wttons: ", data['wttons'].median())
print("Mean Value of wttons: ", data['wttons'].mean())
# Out:
# Median Value of wttons:  11.0
# Mean Value of wttons:  13.630694444444442

# %%
# lets check the values in the demand column
data['demand'].value_counts()
# Out:
# normal    99
# high      94
# less      56
# low        8
# 6          1
# Name: demand, dtype: int64

# %%
# lets use the mode values to impute the demand column
data['demand'] = data['demand'].fillna(data['demand'].mode()[0])
data['demand'].value_counts()
# Out:
# normal    130
# high       94
# less       56
# low         8
# 6           1
# Name: demand, dtype: int64

# %%
# lets check the values in the seasonal impact column
data['seasonalimpact'].value_counts()
# Out:
# yes     165
# no       77
# high      1
# Name: seasonalimpact, dtype: int64

# %%
# lets use the mode values to impute the seasonal impact column
data['seasonalimpact'] = data['seasonalimpact'].fillna(data['seasonalimpact'].mode()[0])
data['seasonalimpact'].value_counts()
# Out:
# yes     211
# no       77
# high      1
# Name: seasonalimpact, dtype: int64

# %%
# lets check the values in the road column
data['road'].value_counts()
# Out:
# nh     184
# sh      49
# yes      1
# Name: road, dtype: int64

# %%
# lets use the mode values to impute the vmissing values in the road columns
data['road'] = data['road'].fillna(data['road'].mode()[0])
data['road'].value_counts()
# Out:
# nh     239
# sh      49
# yes      1
# Name: road, dtype: int64

# %%
# lets check the values in the distance column
data['distance'].median()
# Out:
# 456.0

# %%
# lets  impute the missing values with the median values
data['distance'] = data['distance'].fillna(data['distance'].median())

# %%
# lets check the values in the road column
data['miscellaneous'].median()
# Out:
# 6780.0

# %%
# lets  impute the missing values with the median values
data['miscellaneous'] = data['miscellaneous'].fillna(data['miscellaneous'].median())

# %%
# as we have imputed all the missing values now lets check how many missing values are left
data.isnull().sum()
# Out:
# year              0
# road              0
# seasonalimpact    0
# demand            0
# wttons            0
# labour            0
# toll              0
# distance          0
# fuelcost          0
# miscellaneous     0
# tariff            0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## Encoding Variables

# %%
# encoding of the Variables
# lets check how many categorical variables are present in the columns

x = data.dtypes =='object'
x = x[x == True]
x.index
# Out:
# Index(['road', 'seasonalimpact', 'demand'], dtype='object')

# %%
# lets check the values of demand

data['demand'].value_counts()
# Out:
# normal    130
# high       94
# less       56
# low         8
# 6           1
# Name: demand, dtype: int64

# %%
# lets check the effect of these values with the target variable

data[['demand', 'tariff']].groupby(['demand']).agg('median')
# Out:
#          tariff
# demand
# 6          77.0
# high    11250.5
# less     8202.0
# low     10516.0
# normal   8579.0

# %%
data['demand'] = data['demand'].replace(6, -1)
data['demand'] = data['demand'].replace('high', 2)
data['demand'] = data['demand'].replace('low', 2)
data['demand'] = data['demand'].replace('normal', 1)
data['demand'] = data['demand'].replace('less', 1)

# %%
# lets check the values of seasonal impact

data['seasonalimpact'].value_counts()
# Out:
# yes     211
# no       77
# high      1
# Name: seasonalimpact, dtype: int64

# %%
# lets check the effect of these values with the target variable

data[['seasonalimpact', 'tariff']].groupby(['seasonalimpact']).agg('median')
# Out:
#                 tariff
# seasonalimpact
# high                77
# no                9507
# yes               9370

# %%
# lets check the effect of these values with the target variable

data[['seasonalimpact', 'tariff']].groupby(['seasonalimpact']).agg('std')
# Out:
#                      tariff
# seasonalimpact
# high                    NaN
# no              4649.281079
# yes             4404.222390

# %%
# lets replace  these values

data['seasonalimpact'] = data['seasonalimpact'].replace('yes', 1)
data['seasonalimpact'] = data['seasonalimpact'].replace('no', 1)
data['seasonalimpact'] = data['seasonalimpact'].replace('high', 0)

# %%
# lets check the values of road

data['road'].value_counts()
# Out:
# nh     239
# sh      49
# yes      1
# Name: road, dtype: int64

# %%
# lets check the effect of these values with the target variable

data[['road', 'tariff']].groupby(['road']).agg('median')
# Out:
#       tariff
# road
# nh     10128
# sh      6400
# yes       77

# %%
# lets do label encoding

data['road'] = data['road'].replace('nh', 2)
data['road'] = data['road'].replace('sh', 1)
data['road'] = data['road'].replace('yes', 0)

# %%
# lets check the values in the road column

data['road'].value_counts()
# Out:
# 2    239
# 1     49
# 0      1
# Name: road, dtype: int64

# %%
# as we have encoded all the variables lets check how many are objects

data.dtypes
# Out:
# year                int64
# road                int64
# seasonalimpact      int64
# demand             object
# wttons            float64
# labour              int64
# toll                int64
# distance          float64
# fuelcost            int64
# miscellaneous     float64
# tariff              int64
# dtype: object

# %% [markdown]
# # Data Preparation

# %%
# we know that our target variable is the tariff rate
# lets make it separate

x = data.iloc[:, :-1]
y = data.iloc[:, -1]

# lets check the shape of x and y
print("shape of x :", x.shape)
print("Shape of y :", y.shape)
# Out:
# shape of x : (289, 10)
# Shape of y : (289,)

# %%
# lets visualize x and y
x.head()
# Out:
#    year  road  seasonalimpact demand  ...  toll  distance  fuelcost  miscellaneous
# 0  2013     2               1      2  ...  8200    1460.0     23534         9000.0
# 1  2013     2               1      2  ...  8600    1360.0     22184        10000.0
# 2  2013     2               1      2  ...  8300    1310.0     21476         9400.0
# 3  2013     2               1      2  ...  2400     650.0     10473         6000.0
# 4  2013     2               1      2  ...  3500     560.0      9417         5600.0
#
# [5 rows x 10 columns]

# %%
y.head()
# Out:
# 0    17950
# 1    19710
# 2    18600
# 3     9150
# 4     9700
# Name: tariff, dtype: int64

# %%
# lets split these dependent and independent variables into train and test sets

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, 
                                                    y, 
                                                    test_size = 0.2,
                                                    random_state = 0)

# lets check the shape of the training nad testing sets of dependent and independent variables
print("Shape of x_train :", x_train.shape)
print("Shape of x_test :", x_test.shape)
print("Shape of y_train :", y_train.shape)
print("Shape of y_test :", y_test.shape)
# Out:
# Shape of x_train : (231, 10)
# Shape of x_test : (58, 10)
# Shape of y_train : (231,)
# Shape of y_test : (58,)

# %%
# lets check our x_train and other sets

x_train.head()
# Out:
#      year  road  seasonalimpact demand  ...  toll  distance  fuelcost  miscellaneous
# 46   2013     2               1      1  ...  1980     403.0      6574         5780.0
# 259  2015     2               1      1  ...  2160     558.0     11094         8000.0
# 216  2014     2               1      1  ...  2340     542.3     10276         7500.0
# 168  2014     2               1      2  ...  4600     761.0     14773         7185.0
# 225  2014     2               1      1  ...  1560     275.0      5212         5355.0
#
# [5 rows x 10 columns]

# %%
x_train.style.bar(color = ['red','green'], align = 'zero')
# Out:
# <style  type="text/css" >
# #T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row0_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row0_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row0_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row1_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row1_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row1_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row2_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row2_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row2_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row3_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row3_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row3_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row4_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row4_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row4_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row5_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row5_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row5_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row6_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row6_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row6_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row7_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row7_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row7_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row8_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row8_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row8_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row9_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row9_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row9_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row10_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row10_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row10_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row11_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row11_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row11_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row12_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row12_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row12_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row13_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row13_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row13_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row14_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row14_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row15_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row15_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row15_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row16_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row16_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row16_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row17_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row17_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row17_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row18_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row18_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row18_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row19_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row19_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row19_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row20_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row20_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row20_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row21_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row21_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row21_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row22_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row22_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row22_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row23_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row23_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row24_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row24_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row24_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row25_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row25_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row25_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row26_col0,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row26_col1,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row26_col2,#T_63a1b55a_9a8b_11eb_ac78_0242ac1c0002row27_col0,#T_63a1b55a_9a8b_11eb_ac78_024 ...

# %%
x_test.head()
# Out:
#      year  road  seasonalimpact demand  ...  toll  distance  fuelcost  miscellaneous
# 55   2013     2               1      1  ...  1545     240.0      3934         5860.0
# 182  2014     1               1      1  ...     0     179.0      3526         6675.0
# 92   2013     2               1      1  ...  2900     329.0      5326         5700.0
# 209  2014     2               1      2  ...  3400     586.0     10928         7500.0
# 261  2015     2               1      1  ...  1740     274.0      5455         7200.0
#
# [5 rows x 10 columns]

# %%
y_train.head()
# Out:
# 46      8558
# 259    11240
# 216    10800
# 168    12739
# 225     7461
# Name: tariff, dtype: int64

# %%
y_test.head()
# Out:
# 55      8231
# 182     7555
# 92      9370
# 209    11980
# 261     9732
# Name: tariff, dtype: int64

# %% [markdown]
# # Feature Scaling

# %%
# lets do standardization of the data to get better results

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# lets check the shape of sets
print("Shape of x_train :", x_train.shape)
print("Shape of x_test :", x_test.shape)
# Out:
# Shape of x_train : (231, 10)
# Shape of x_test : (58, 10)

# %%
x_train_viz = pd.DataFrame(x_train)
x_train_viz.style.bar(color = ['red','green'], align = 'mid')
# Out:
# <style  type="text/css" >
# #T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row0_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row6_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row9_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row13_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row20_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row21_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row26_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row28_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row33_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row39_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row40_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row42_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row45_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row46_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row48_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row49_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row50_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row55_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row57_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row58_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row60_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row61_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row62_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row63_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row65_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row66_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row71_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row73_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row74_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row76_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row79_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row80_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row81_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row84_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row88_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row89_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row90_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row92_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row94_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row95_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row97_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row98_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row99_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row101_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row106_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row112_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row118_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row120_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row122_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row125_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row127_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row128_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row129_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row130_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row133_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row134_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row135_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row136_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row139_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row143_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row145_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row151_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row152_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row154_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row162_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row163_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row165_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row167_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row168_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row169_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row171_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row172_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row176_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row177_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row179_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row180_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row182_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row184_col0,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row188_col0,#T_63d8c23e_9a8b_ ...
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 37.9%, transparent 37.9%);
#         }#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row0_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row1_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row2_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row3_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row4_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row5_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row6_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row7_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row8_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row9_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row10_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row11_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row12_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row13_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row15_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row16_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row17_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row18_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row19_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row20_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row21_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row22_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row24_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row25_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row26_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row27_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row28_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row30_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row31_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row32_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row33_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row35_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row36_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row37_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row39_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row40_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row41_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row44_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row45_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row46_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row50_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row52_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row53_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row54_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row56_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row57_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row58_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row59_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row60_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row61_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row62_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row63_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row64_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row65_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row66_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row67_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row68_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row69_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row70_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row71_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row72_col1,#T_63d8c23e_9a8b_11eb_ac78_0242ac1c0002row74_

# %%
x_test_viz = pd.DataFrame(x_test)
x_test_viz.style.bar(color = ['red','green'], align = 'mid')
# Out:
# <style  type="text/css" >
# #T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row0_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row2_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row5_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row6_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row8_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row9_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row12_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row13_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row14_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row22_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row24_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row25_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row31_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row32_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row34_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row36_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row37_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row38_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row39_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row40_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row48_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row50_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row54_col0,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row57_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,red 37.9%, transparent 37.9%);
#         }#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row0_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row2_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row3_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row4_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row5_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row6_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row7_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row8_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row10_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row12_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row14_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row15_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row16_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row17_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row18_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row20_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row21_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row22_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row23_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row24_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row25_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row26_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row27_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row28_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row29_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row30_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row31_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row32_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row34_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row35_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row36_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row37_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row38_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row40_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row41_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row42_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row43_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row44_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row46_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row47_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row48_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row49_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row50_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row51_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row52_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row53_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row54_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row55_col1,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row57_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 91.1%, green 91.1%, green 100.0%, transparent 100.0%);
#         }#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row0_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row1_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row2_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row3_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row4_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row5_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row6_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row7_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row8_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row9_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row10_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row11_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row12_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row13_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row14_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row15_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row16_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row17_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row18_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row19_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row20_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row21_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row22_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row23_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row24_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row25_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row26_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row27_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row28_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row29_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row30_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row31_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row32_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row33_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row34_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row35_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row36_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row37_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row38_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row39_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row40_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row41_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row42_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row43_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row44_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row45_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row46_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row47_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row48_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row49_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row50_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row51_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row52_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row53_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row54_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row55_col2,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row57_col2{
#             width:  10em;
#              height:  80%;
#         }#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row0_col3,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row1_col3,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row2_col3,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row4_col3,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row5_col3,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row6_col3,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row11_col3,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row13_col3,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row14_col3,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row15_col3,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row17_col3,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row18_col3,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row20_col3,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row21_col3,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row22_col3,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row24_col3,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row25_col3,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row26_col3,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row30_col3,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row31_col3,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row33_col3,#T_63f668a2_9a8b_11eb_ac78_0242ac1c0002row34_col3,#T_63f668a2_9a8b_11eb_

# %% [markdown]
# # Modelling

# %% [markdown]
# ### Linear Regression

# %%
# lets do the Modelling

# It is a Regression Problem

# linear Regression
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

print("Training Accuracy :", model.score(x_train, y_train))
print("Testing Accuracy :", model.score(x_test, y_test))
# Out:
# Training Accuracy : 0.9999845250297132
# Testing Accuracy : 0.9452800682648779

# %%
# checking the accuracy of the model

from sklearn.metrics import mean_squared_error

error = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(error)
print(rmse)
# Out:
# 1232.6549608443377

# %%
# lets check the r2 score of the model

from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.9452800682648779

# %%
# lets check the mean, median, standard deviation etc of the predictions

print("Mean of the Predictions :", y_pred.mean())
print("Maxima of the Predictions :",y_pred.max())
print("Minima of the Predictions :",y_pred.min())
print("Standard Deviation of the Predictions :", y_pred.std())

pred = pd.DataFrame(y_pred)
print("Median of the Predictions :",pred.median())
# Out:
# Mean of the Predictions : 10757.057518723434
# Maxima of the Predictions : 32031.031156659483
# Minima of the Predictions : 4497.16330965962
# Standard Deviation of the Predictions : 5078.804896407285
# Median of the Predictions : 0    9397.006005
# dtype: float64

# %%
pred.style.bar(color = 'orange', align = 'mid')
# Out:
# <style  type="text/css" >
# #T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 25.7%, transparent 25.7%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 23.6%, transparent 23.6%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 29.3%, transparent 29.3%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 37.4%, transparent 37.4%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 30.3%, transparent 30.3%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 20.8%, transparent 20.8%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row6_col0,#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row48_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 29.8%, transparent 29.8%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 43.5%, transparent 43.5%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 100.0%, transparent 100.0%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 20.0%, transparent 20.0%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row10_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 61.4%, transparent 61.4%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row11_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 24.2%, transparent 24.2%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row12_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 62.4%, transparent 62.4%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row13_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 14.0%, transparent 14.0%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row14_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 22.5%, transparent 22.5%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row15_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 30.2%, transparent 30.2%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row16_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 31.9%, transparent 31.9%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row17_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 40.1%, transparent 40.1%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row18_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 57.8%, transparent 57.8%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row19_col0,#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row47_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 24.5%, transparent 24.5%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row20_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 21.9%, transparent 21.9%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row21_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 26.0%, transparent 26.0%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row22_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 20.2%, transparent 20.2%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row23_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 24.0%, transparent 24.0%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row24_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 18.3%, transparent 18.3%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row25_col0,#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row40_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 28.6%, transparent 28.6%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row26_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 19.2%, transparent 19.2%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row27_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 22.6%, transparent 22.6%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row28_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 45.3%, transparent 45.3%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row29_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 29.9%, transparent 29.9%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row30_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 38.2%, transparent 38.2%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row31_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 20.5%, transparent 20.5%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row32_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 66.7%, transparent 66.7%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row33_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 18.1%, transparent 18.1%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row34_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 59.3%, transparent 59.3%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row35_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 35.2%, transparent 35.2%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row36_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 26.7%, transparent 26.7%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row37_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 25.1%, transparent 25.1%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row38_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 31.5%, transparent 31.5%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row39_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 14.4%, transparent 14.4%);
#         }#T_6426f6c0_9a8b_11eb_ac78_0242ac1c0002row41_col0{
#             width:  1

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

print("Training Accuracy :", model.score(x_train, y_train))
print("Testing Accuracy :", model.score(x_test, y_test))
# Out:
# Training Accuracy : 1.0
# Testing Accuracy : 0.881113186208534

# %%
# checking the accuracy of the model

from sklearn.metrics import mean_squared_error

error = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(error)
print(rmse)
# Out:
# 1816.9191335695252

# %%
# lets check the r2 score of the model

from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.881113186208534

# %%
# lets check the mean, median, standard deviation etc of the predictions

print("Mean of the Predictions :", y_pred.mean())
print("Maxima of the Predictions :",y_pred.max())
print("Minima of the Predictions :",y_pred.min())
print("Standard Deviation of the Predictions :", y_pred.std())

pred = pd.DataFrame(y_pred)
print("Median of the Predictions :",pred.median())
# Out:
# Mean of the Predictions : 10633.672413793103
# Maxima of the Predictions : 21684.0
# Minima of the Predictions : 4590.0
# Standard Deviation of the Predictions : 4563.82485304147
# Median of the Predictions : 0    9331.0
# dtype: float64

# %% [markdown]
# ### Few more algorithms can also be used to ahchieve various accuracies.

# %% [markdown]
# ## Thank You !
